# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Show the data

# %%
import pandas as pd
df=pd.read_csv('HRdata.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## Show the data information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Show the columns name

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Top 5 values

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Last 5 values

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# ## Show the unique data

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Returns the number of missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Show the duplicate data

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %% [markdown]
# ## Drop the null values

# %%
 df.dropna()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## Attrition Distribution

# %%
att=pd.DataFrame(df["Attrition"].value_counts())
att
# Out:
#      Attrition
# No        1233
# Yes        237

# %%
import matplotlib.pyplot as plt
plt.pie(att_count["Attrition"],labels=['No','Yes'],autopct='%.1f%%', explode=(0.2,0))
plt.show()

# %% [markdown]
# ## Attrition of the Age Group

# %%
df['Age'].value_counts()
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64

# %%
df['Age'].value_counts().plot(kind='bar', figsize=(12,4), color="green", fontsize=13)

plt.xlabel("Age Group", fontsize=12)
plt.ylabel("Count of People", fontsize=12)
plt.title("Attrition of the Age", fontsize=16)
plt.show()

# %% [markdown]
# ## Histogram of Age

# %%
df["Age"].nunique()
# Out:
# 43

# %%
df.hist(column="Age",
         grid=False,
         figsize=(6,4),
         color="indigo",
         edgecolor="black",
         bins=12)

plt.xlabel("Age values",fontsize=12)
plt.ylabel("frequency of emp",fontsize=12)
plt.title("Histogram of Age",fontsize=16)

plt.show()

# %% [markdown]
# ## Attrition of the BusinessTravel

# %%
df['BusinessTravel'].value_counts().plot(kind='barh', figsize=(12,4), color="cyan", fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("Attrition", fontsize=12)
plt.title("Attrition of the BusinessTravel", fontsize=16)
plt.show()

# %% [markdown]
# ## Attrition of the Department

# %%
df["Department"].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
labels = ['Research & Development', 'Sales', 'Human Resources']
plt.pie(df.Department.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %% [markdown]
# ## Attrition of the Gender

# %%
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='barh', figsize=(12,4), color="Yellow", fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("Attrition", fontsize=12)
plt.title("Attrition of the 'Gender'", fontsize=16)
plt.show()

# %% [markdown]
# ## Attrition of the MaritalStatus

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts().plot(kind='bar', figsize=(12,4), color="green", fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("Attrition", fontsize=12)
plt.title("Attrition of the MaritalStatus", fontsize=16)
plt.show()

# %%
labels = ['Married', 'Single','Divorced']
plt.pie(df.MaritalStatus.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [markdown]
# ## Attrition of the Monthly Income

# %%
df.MonthlyIncome.describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# ## Attrition of the EducationField

# %%
labels = ['Life Sciences', 'Medical', 'Marketing','Technical Degree','Other','Human Resources']
plt.pie(df.EducationField.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %% [markdown]
# ## Attrition of the JobRole

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
df['JobRole'].value_counts().plot(kind='barh', figsize=(12,4), color="cyan", fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("Attrition", fontsize=12)
plt.title("Attrition of the JobRole", fontsize=16)
plt.show()

# %% [markdown]
# ## Attrition of the JobSatisfaction

# %%
df["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64

# %%
df['JobSatisfaction'].value_counts().plot(kind='bar', figsize=(12,4), color="Blue", fontsize=13)

plt.xlabel("Count of people", fontsize=12)
plt.ylabel("Attrition", fontsize=12)
plt.title("Attrition of the JobSatisfaction", fontsize=16)
plt.show()

# %%
labels = ['4', '3','1','2']
plt.pie(df.JobSatisfaction.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %% [markdown]
# ##  Attrition of the worklifeBalance

# %%
df["WorkLifeBalance"].value_counts()
# Out:
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64

# %%
labels = ['3', '2','4','1']
plt.pie(df.WorkLifeBalance.value_counts(), labels=labels,autopct='%.1f%%')
plt.show()

# %% [markdown]
# ## Attrition of the YearsAtCompany

# %%
df.YearsAtCompany.describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %%
df['YearsAtCompany'].value_counts().plot(kind='bar', figsize=(19,4), color="Blue", fontsize=13)

plt.xlabel("Years At Company", fontsize=12)
plt.ylabel("Count of Employees", fontsize=12)
plt.show()

# %% [markdown]
# ## Attrition of the Distance From Home

# %%
df.DistanceFromHome.describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
df['DistanceFromHome'].value_counts().plot(kind='bar', figsize=(10,6), color="Green", fontsize=13)

plt.xlabel("Distance From Home", fontsize=12)
plt.ylabel("Count of Employees", fontsize=12)
plt.title(" Employee 'Distance From Home' Analysis ", fontsize=16)
plt.show()

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## Attrition Count

# %%
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(x="Attrition", data=df)
plt.title("Attrition Count")
plt.show()

# %% [markdown]
# ## Age Distribution

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# ## Relation scatterplot between Monthly Income vs Age

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x="Age", y="MonthlyIncome", data=df, hue="Attrition")
plt.title("Age vs. Monthly Income")
plt.show()

# %% [markdown]
# ## Relation scatterplot between Monthly Income vs Years at Company

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x="YearsAtCompany", y="MonthlyIncome", data=df, hue="Attrition")
plt.title("Years at Company vs. Monthly Income")
plt.show()

# %% [markdown]
# # Featurs Important

# %% [markdown]
# ## What age group is more likely to leave?

# %%
t = pd.crosstab(df.Age,columns = df.Attrition)
t
# Out:
# Attrition  No  Yes
# Age
# 18          4    4
# 19          3    6
# 20          5    6
# 21          7    6
# 22         11    5
# 23         10    4
# 24         19    7
# 25         20    6
# 26         27   12
# 27         45    3
# 28         34   14
# 29         50   18
# 30         51    9
# 31         51   18
# 32         50   11
# 33         46   12
# 34         68    9
# 35         68   10
# 36         63    6
# 37         44    6
# 38         56    2
# 39         36    6
# 40         52    5
# 41         34    6
# 42         44    2
# 43         30    2
# 44         27    6
# 45         39    2
# 46         29    4
# 47         21    3
# 48         17    2
# 49         22    2
# 50         25    5
# 51         17    2
# 52         15    3
# 53         17    2
# 54         18    0
# 55         19    3
# 56         11    3
# 57          4    0
# 58          9    5
# 59         10    0
# 60          5    0

# %%
plt.subplots (figsize=(15,4))
sns.countplot (x='Age',  hue='Attrition', data= df, palette = 'colorblind')
plt.show()

# %% [markdown]
# ## Correlation of data

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %% [markdown]
# ## Heatmap of correlation

# %%
import seaborn as sns
sns.heatmap(df.corr())              
plt.show()

# %% [markdown]
# # visualization

# %% [markdown]
# ## Monthly income by department

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x="Department", y="MonthlyIncome", data=df)
plt.title("Monthly Income by Department")
plt.xlabel("Department")
plt.ylabel("Monthly Income")
plt.xticks(rotation=45)  
plt.show()

# %% [markdown]
# ## Attrition by Age group

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="Age", hue="Attrition", data=df)
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title("Employee Attrition by Age Group")
plt.show()

# %% [markdown]
# ## Attrition by education level

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x="Education", y="Attrition", data=df)
plt.title("Attrition by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Attrition")
plt.show()

# %% [markdown]
# ## Relation plot between Monthly Income and Age by Marital status

# %%
sns.relplot(x="MonthlyIncome",y="Age",hue="MaritalStatus",data=df)   
plt.show()

# %% [markdown]
# ## Relation between Employee's  YearsAtCompany and their age with attrition

# %%
sns.pairplot(df, vars=["YearsAtCompany","Age","MonthlyIncome"])
plt.show()

# %% [markdown]
# #  Findings after performing Analysis :-
#
# ## Based on Age:
# Range of age is between 18 years to 60 years: This company has employees across the spectrum from recent graduates to the retirement age. Since the maximum age bracket with highest number of employees are between 29 -40, we can safely assume that the company prefers employees who have considerable work experience.
#
# ## Based on Department:
# Since 65% of the employees are in Research and development, we can assume that the company activities include innovation and introducing new products and services.
#
# ## Based on Gender:
# The number of male is 882 more than the female employees of 588.
#
# ## Based on Marital Status:
# As 45% of the employees in the organization are married, the company appears to give a stable and well-paying job profile to the employees. Marital status is also an important indicator of organizational commitment. Generally, married people are more committed to their organization than unmarried people.
#
#
# ## Based on Education Field:
# Since 41% and 31% of the employees are from the Life sciences and medical backgrounds respectively, we can say that the company is majorly based out of bio-technology and R&D. This further strengthens our earlier propositions.
# ## Based of Job Role
# The highest number of job role is Sales Executive 326. The lowest number of job role is Human Resource 52. Because HR role is limited and work in office.
#
# ## Based on Job Satisfaction:
# Only 30% of employees in the organization have given the highest rating for job satisfaction. This shows that there is still a lot of room for improvement.
#
# ## Based on Work Life Balance :
# 60% of employees have given third best rating.
# ## Based on Years At Company:
# The dataset reveals that a majority of the employees (75%) have a work experience of less than 9 years at the company.
#
# ## Based on Distance From Home:
# A large number of employees are residing close to the company (50% of the employees are at a distance of 7km). There is a possibility that accommodation facilities are provided by the company, since the maximum count of employees are at a distance of 2 km.
#
#
# ## Based of Job Role
# The highest number of job role is Sales Executive 326. The lowest number of job role is Human Resource 52. Because HR role is limited and work in office.
